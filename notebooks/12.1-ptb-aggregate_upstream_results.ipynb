# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

results_both = []
for channels in range(12):
    try:
        with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/ptb-{channels}_channels_off-no_additional_noise-impute_only_missing/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
            b = pickle.load(handle)
        bdf = pd.DataFrame(b)
        results_both.append(bdf)
    except:
        continue
results_both = pd.concat(results_both,axis=0,ignore_index=True)
results_both.to_csv("/home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/ptb-upstream-results.csv", index=False)
results_both
# Out:
#      channels_to_turn_off  seed  validation-roc-auc  validation-pr-auc  \
# 0                       0   510            0.876948           0.429848
# 1                       0   365            0.789679           0.202808
# 2                       0   382            0.846970           0.298249
# 3                       0   322            0.864839           0.339942
# 4                       0   988            0.760318           0.218011
# ..                    ...   ...                 ...                ...
# 169                    11   988            0.756284           0.213635
# 170                    11    98            0.763018           0.197227
# 171                    11   742            0.775698           0.210890
# 172                    11    17            0.748143           0.214571
# 173                    11   595            0.763965           0.203613
#
#      test-roc-auc  test-pr-auc
# 0        0.791983     0.134370
# 1        0.653175     0.085361
# 2        0.807184     0.131503
# 3        0.760986     0.169675
# 4        0.736551     0.112367
# ..            ...          ...
# 169      0.694679     0.113026
# 170      0.686800     0.114868
# 171      0.694329     0.122113
# 172      0.669237     0.106613
# 173      0.701387     0.110479
#
# [174 rows x 6 columns]

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

results_both = []
for channels in range(12):
    try:
        with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/ptb-{channels}_channels_off-no_additional_noise-impute_only_missing-unfreeze_upstream_weights/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
            b = pickle.load(handle)
        bdf = pd.DataFrame(b)
        results_both.append(bdf)
    except:
        continue
results_both = pd.concat(results_both,axis=0,ignore_index=True)
results_both.to_csv("/home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/ptb-upstream-results-unfreeze_upstream_weights.csv", index=False)
results_both
# Out:
#      channels_to_turn_off  seed  validation-roc-auc  validation-pr-auc  \
# 0                       1   510            0.876582           0.389797
# 1                       1   365            0.881851           0.365952
# 2                       1   382            0.876975           0.376188
# 3                       1   322            0.892719           0.364925
# 4                       1   988            0.877488           0.352851
# ..                    ...   ...                 ...                ...
# 105                    11    98            0.774428           0.202528
# 106                    11   742            0.744985           0.208445
# 107                    11    17            0.806466           0.254802
# 108                    11   595            0.768312           0.218919
# 109                    11   106            0.776451           0.191113
#
#      test-roc-auc  test-pr-auc
# 0        0.807270     0.174111
# 1        0.799565     0.179967
# 2        0.763349     0.176061
# 3        0.766011     0.162637
# 4        0.796865     0.174569
# ..            ...          ...
# 105      0.686663     0.109692
# 106      0.656959     0.112207
# 107      0.721876     0.121610
# 108      0.715413     0.121657
# 109      0.702982     0.116739
#
# [110 rows x 6 columns]
