# %% [markdown]
# # Summary
# In this notebook we construct a combined model, that is expecting a 12-leads ECG readings, first impute their empty values (using the upstream model's weights) and then takes the imputed ECG signal and use it to predict the target(s).
# We do not train anything yet.

# %% [markdown]
# # Setup

# %%
import os
os.chdir('/home/david/Desktop/projects/thesis/')

# %%
import torch

# hyperparams to be changed if needed
downstream_path = './downstream_classification/models/3.0-inception-bs128-balanced-death-lr0.001-decay0-aucpr-weighted33.pt'
upstream_path = './upstream_seq2seq/models/transformer_cnn_1696038569.0264485.pt'
lr,dropout,class_weight,weight_decay = (0.001, 0.2, 50.0, 0.0005)

## upstream

input_dimension          = 12
output_dimension         = 12
hidden_dimmension        = 64
attention_heads          = None
encoder_number_of_layers = 8
dim_feedforward          = 512
kernel_size              = 3
activation               ='gelu'
dropout                  = 0.4
device                   = device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
loss_function_weight     = torch.tensor([50]).to(device)
# ---------------

# %%
from combined_downstream_upstram.executors.train_on_local_machine_mps import trainer

for lr in [0.0005,0.001,0.003]:
    for class_weight in [33,50,66,100]:
        for weight_decay in [0,0.0001,0.0005,0.001]:
            loss_function_weight = torch.tensor([class_weight]).to(device)
            config = {
                # general
                'seed': 123,
                'metadata_file_path': './downstream_classification/data/combined_data/metadata_only_existant_readings_09042023.csv',
                'data_folder_path': './downstream_classification/data/individual-signals/',
                'fillna': 0,
                # training
                'batch_size': 64,
                'n_epochs': 60,
                'clip':1,
                'loss_function_weight':loss_function_weight,
                'targets': ['one_year_until_death'],
                'saving_path': f'./combined_downstream_upstram/models/comined_model_training/comined_model_training_{lr}_{class_weight}_{weight_decay}',
                'lr': lr,
                'impute_only_missing':True,
                'weight_decay':weight_decay,
                'patience':5
            }

            import os

            # run
            print('Starting Experiment')
            trainer(**config)
# Out:
# Starting Experiment
#
#
# training using device: cuda
# /home/david/anaconda3/envs/thesis_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:218: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because  self.layers[0].self_attn.batch_first was not True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 1320081
# Within epoch loss (training) 4.28457: 100%|██████████| 4103/4103 [08:40<00:00,  7.88it/s]
# Within epoch loss (validation) 3.98446: 100%|██████████| 832/832 [01:59<00:00,  6.95it/s]
# New best validation loss was found, current best valid loss is 3.9845
# ---------------------------------------------
# Epoch: 01 | Time: 10m 42s
# 	Train Loss: 4.285
# 	 Val. Loss: 3.984
# 	 ROC-AUC: 0.627
# 	 PR-AUC: 0.043
# 	 TPR for FPR=0.6 Budget: 0.755
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.2356: 100%|██████████| 4103/4103 [08:54<00:00,  7.68it/s]
# Within epoch loss (validation) 3.98667: 100%|██████████| 832/832 [01:28<00:00,  9.44it/s]
# ---------------------------------------------
# Epoch: 02 | Time: 10m 24s
# 	Train Loss: 4.236
# 	 Val. Loss: 3.987
# 	 ROC-AUC: 0.633
# 	 PR-AUC: 0.045
# 	 TPR for FPR=0.6 Budget: 0.759
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.18865: 100%|██████████| 4103/4103 [08:28<00:00,  8.07it/s]
# Within epoch loss (validation) 4.00131: 100%|██████████| 832/832 [01:31<00:00,  9.07it/s]
# ---------------------------------------------
# Epoch: 03 | Time: 10m 1s
# 	Train Loss: 4.189
# 	 Val. Loss: 4.001
# 	 ROC-AUC: 0.636
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.759
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.15586: 100%|██████████| 4103/4103 [08:28<00:00,  8.08it/s]
# Within epoch loss (validation) 4.01568: 100%|██████████| 832/832 [01:29<00:00,  9.28it/s]
# ---------------------------------------------
# Epoch: 04 | Time: 9m 59s
# 	Train Loss: 4.156
# 	 Val. Loss: 4.016
# 	 ROC-AUC: 0.636
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.758
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.12407: 100%|██████████| 4103/4103 [09:35<00:00,  7.13it/s]
# Within epoch loss (validation) 4.03311: 100%|██████████| 832/832 [01:56<00:00,  7.12it/s]
# ---------------------------------------------
# Epoch: 05 | Time: 11m 35s
# 	Train Loss: 4.124
# 	 Val. Loss: 4.033
# 	 ROC-AUC: 0.634
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.755
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.10418: 100%|██████████| 4103/4103 [08:26<00:00,  8.10it/s]
# Within epoch loss (validation) 4.02968: 100%|██████████| 832/832 [01:27<00:00,  9.46it/s]
# ---------------------------------------------
# Epoch: 06 | Time: 9m 57s
# 	Train Loss: 4.104
# 	 Val. Loss: 4.030
# 	 ROC-AUC: 0.638
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.770
# 	 Best Val. Loss: 3.984
# ---------------------------------------------
# Within epoch loss (training) 4.06261: 100%|██████████| 4103/4103 [09:28<00:00,  7.21it/s]
# Within epoch loss (validation) 4.0528: 100%|██████████| 832/832 [01:29<00:00,  9.34it/s]
# Starting Experiment
#
#
# training using device: cuda
# /home/david/anaconda3/envs/thesis_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:218: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because  self.layers[0].self_attn.batch_first was not True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 1320081
# Within epoch loss (training) 4.29117: 100%|██████████| 4103/4103 [08:56<00:00,  7.65it/s]
# Within epoch loss (validation) 3.95499: 100%|██████████| 832/832 [01:55<00:00,  7.21it/s]
# New best validation loss was found, current best valid loss is 3.955
# ---------------------------------------------
# Epoch: 01 | Time: 10m 53s
# 	Train Loss: 4.291
# 	 Val. Loss: 3.955
# 	 ROC-AUC: 0.628
# 	 PR-AUC: 0.044
# 	 TPR for FPR=0.6 Budget: 0.761
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.22846: 100%|██████████| 4103/4103 [08:40<00:00,  7.88it/s]
# Within epoch loss (validation) 4.0046: 100%|██████████| 832/832 [01:30<00:00,  9.19it/s]
# ---------------------------------------------
# Epoch: 02 | Time: 10m 13s
# 	Train Loss: 4.228
# 	 Val. Loss: 4.005
# 	 ROC-AUC: 0.628
# 	 PR-AUC: 0.045
# 	 TPR for FPR=0.6 Budget: 0.747
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.1967: 100%|██████████| 4103/4103 [08:56<00:00,  7.65it/s]
# Within epoch loss (validation) 3.97869: 100%|██████████| 832/832 [01:29<00:00,  9.33it/s]
# ---------------------------------------------
# Epoch: 03 | Time: 10m 27s
# 	Train Loss: 4.197
# 	 Val. Loss: 3.979
# 	 ROC-AUC: 0.635
# 	 PR-AUC: 0.047
# 	 TPR for FPR=0.6 Budget: 0.751
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.1532: 100%|██████████| 4103/4103 [09:25<00:00,  7.26it/s]
# Within epoch loss (validation) 4.00488: 100%|██████████| 832/832 [01:28<00:00,  9.36it/s]
# ---------------------------------------------
# Epoch: 04 | Time: 10m 55s
# 	Train Loss: 4.153
# 	 Val. Loss: 4.005
# 	 ROC-AUC: 0.635
# 	 PR-AUC: 0.047
# 	 TPR for FPR=0.6 Budget: 0.761
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.12985: 100%|██████████| 4103/4103 [08:30<00:00,  8.04it/s]
# Within epoch loss (validation) 4.02195: 100%|██████████| 832/832 [01:29<00:00,  9.25it/s]
# ---------------------------------------------
# Epoch: 05 | Time: 10m 2s
# 	Train Loss: 4.130
# 	 Val. Loss: 4.022
# 	 ROC-AUC: 0.632
# 	 PR-AUC: 0.047
# 	 TPR for FPR=0.6 Budget: 0.761
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.10483: 100%|██████████| 4103/4103 [08:44<00:00,  7.83it/s]
# Within epoch loss (validation) 4.02888: 100%|██████████| 832/832 [01:58<00:00,  7.00it/s]
# ---------------------------------------------
# Epoch: 06 | Time: 10m 45s
# 	Train Loss: 4.105
# 	 Val. Loss: 4.029
# 	 ROC-AUC: 0.637
# 	 PR-AUC: 0.048
# 	 TPR for FPR=0.6 Budget: 0.764
# 	 Best Val. Loss: 3.955
# ---------------------------------------------
# Within epoch loss (training) 4.06327: 100%|██████████| 4103/4103 [09:03<00:00,  7.55it/s]
# Within epoch loss (validation) 4.06159: 100%|██████████| 832/832 [01:30<00:00,  9.16it/s]
# Starting Experiment
#
#
# training using device: cuda
# /home/david/anaconda3/envs/thesis_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:218: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because  self.layers[0].self_attn.batch_first was not True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 1320081
# Within epoch loss (training) 4.28512: 100%|██████████| 4103/4103 [08:38<00:00,  7.92it/s]
# Within epoch loss (validation) 3.96937: 100%|██████████| 832/832 [01:29<00:00,  9.28it/s]
# New best validation loss was found, current best valid loss is 3.9694
# ---------------------------------------------
# Epoch: 01 | Time: 10m 9s
# 	Train Loss: 4.285
# 	 Val. Loss: 3.969
# 	 ROC-AUC: 0.626
# 	 PR-AUC: 0.043
# 	 TPR for FPR=0.6 Budget: 0.760
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.23068: 100%|██████████| 4103/4103 [08:36<00:00,  7.94it/s]
# Within epoch loss (validation) 3.96952: 100%|██████████| 832/832 [01:30<00:00,  9.15it/s]
# ---------------------------------------------
# Epoch: 02 | Time: 10m 9s
# 	Train Loss: 4.231
# 	 Val. Loss: 3.970
# 	 ROC-AUC: 0.632
# 	 PR-AUC: 0.045
# 	 TPR for FPR=0.6 Budget: 0.754
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.19243: 100%|██████████| 4103/4103 [08:38<00:00,  7.91it/s]
# Within epoch loss (validation) 4.06593: 100%|██████████| 832/832 [01:31<00:00,  9.07it/s]
# ---------------------------------------------
# Epoch: 03 | Time: 10m 11s
# 	Train Loss: 4.192
# 	 Val. Loss: 4.066
# 	 ROC-AUC: 0.636
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.763
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.16244: 100%|██████████| 4103/4103 [08:40<00:00,  7.89it/s]
# Within epoch loss (validation) 4.01597: 100%|██████████| 832/832 [01:32<00:00,  8.98it/s]
# ---------------------------------------------
# Epoch: 04 | Time: 10m 14s
# 	Train Loss: 4.162
# 	 Val. Loss: 4.016
# 	 ROC-AUC: 0.634
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.761
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.12775: 100%|██████████| 4103/4103 [08:37<00:00,  7.92it/s]
# Within epoch loss (validation) 4.04602: 100%|██████████| 832/832 [01:29<00:00,  9.26it/s]
# ---------------------------------------------
# Epoch: 05 | Time: 10m 10s
# 	Train Loss: 4.128
# 	 Val. Loss: 4.046
# 	 ROC-AUC: 0.629
# 	 PR-AUC: 0.045
# 	 TPR for FPR=0.6 Budget: 0.750
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.10772: 100%|██████████| 4103/4103 [09:31<00:00,  7.19it/s]
# Within epoch loss (validation) 4.05491: 100%|██████████| 832/832 [01:31<00:00,  9.06it/s]
# ---------------------------------------------
# Epoch: 06 | Time: 11m 5s
# 	Train Loss: 4.108
# 	 Val. Loss: 4.055
# 	 ROC-AUC: 0.632
# 	 PR-AUC: 0.045
# 	 TPR for FPR=0.6 Budget: 0.756
# 	 Best Val. Loss: 3.969
# ---------------------------------------------
# Within epoch loss (training) 4.07249: 100%|██████████| 4103/4103 [08:33<00:00,  7.99it/s]
# Within epoch loss (validation) 4.06574: 100%|██████████| 832/832 [01:29<00:00,  9.26it/s]
# Starting Experiment
#
#
# training using device: cuda
# /home/david/anaconda3/envs/thesis_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:218: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because  self.layers[0].self_attn.batch_first was not True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 1320081
# Within epoch loss (training) 4.28618: 100%|██████████| 4103/4103 [09:35<00:00,  7.12it/s]
# Within epoch loss (validation) 3.99103: 100%|██████████| 832/832 [01:54<00:00,  7.27it/s]
# New best validation loss was found, current best valid loss is 3.991
# ---------------------------------------------
# Epoch: 01 | Time: 11m 31s
# 	Train Loss: 4.286
# 	 Val. Loss: 3.991
# 	 ROC-AUC: 0.625
# 	 PR-AUC: 0.043
# 	 TPR for FPR=0.6 Budget: 0.758
# 	 Best Val. Loss: 3.991
# ---------------------------------------------
# Within epoch loss (training) 4.24583: 100%|██████████| 4103/4103 [08:47<00:00,  7.78it/s]
# Within epoch loss (validation) 4.00666: 100%|██████████| 832/832 [01:31<00:00,  9.08it/s]
# ---------------------------------------------
# Epoch: 02 | Time: 10m 20s
# 	Train Loss: 4.246
# 	 Val. Loss: 4.007
# 	 ROC-AUC: 0.623
# 	 PR-AUC: 0.043
# 	 TPR for FPR=0.6 Budget: 0.745
# 	 Best Val. Loss: 3.991
# ---------------------------------------------
# Within epoch loss (training) 4.19886: 100%|██████████| 4103/4103 [08:42<00:00,  7.86it/s]
# Within epoch loss (validation) 3.98669: 100%|██████████| 832/832 [01:30<00:00,  9.15it/s]
# New best validation loss was found, current best valid loss is 3.9867
# ---------------------------------------------
# Epoch: 03 | Time: 10m 15s
# 	Train Loss: 4.199
# 	 Val. Loss: 3.987
# 	 ROC-AUC: 0.635
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.763
# 	 Best Val. Loss: 3.987
# ---------------------------------------------
# Within epoch loss (training) 4.16841: 100%|██████████| 4103/4103 [08:32<00:00,  8.01it/s]
# Within epoch loss (validation) 4.01419: 100%|██████████| 832/832 [01:42<00:00,  8.09it/s]
# ---------------------------------------------
# Epoch: 04 | Time: 10m 17s
# 	Train Loss: 4.168
# 	 Val. Loss: 4.014
# 	 ROC-AUC: 0.634
# 	 PR-AUC: 0.046
# 	 TPR for FPR=0.6 Budget: 0.757
# 	 Best Val. Loss: 3.987
# ---------------------------------------------
# Within epoch loss (training) 4.1309: 100%|██████████| 4103/4103 [08:47<00:00,  7.78it/s]
# Within epoch loss (validation) 4.06688: 100%|██████████| 832/832 [01:30<00:00,  9.18it/s]

# %%
print('finished')
# Out:
# finished
