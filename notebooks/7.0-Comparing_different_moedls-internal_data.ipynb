# %% [markdown]
# # Summary
# | Experiment in boxplots | Experiment number in code | Status |
# | ---------------------- | ------------------------- | ------ |
# | 2b - warm-start_train-only-downstream, registered | 6b | Done |
# | 5b - upstream-warm-downstream-cold-train-only-downstream | 8b | Done|
# | 6b - warm-start_train-both_impute-only-missing | 9b | Running |
# | 8b - warm-start_train-both_dynamic-reconstruction | 11b | Code is written |
#
# - Plot can be taken from notebook 4.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Normalized Experiments

# %%
import os
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# for exp in ['6', '6b', '8', '8b','9', '9b']:
tites = ['warm-start_train-both',
         'only downstream',
         'only downstream, registered',
         'warm start, train both, registered', 
         'warm-start, train-only-downstream, registered',
         'upstream-warm-downstream-cold-train-only-downstream',
         'warm-start_train-both_impute-only-missing',
         'warm-start_train-both_dynamic-reconstruction',
         'warm-start_train-both_impute-only-missing-reg-downstream',
         ]

res_df = {
      'test':[],
      'score':[]
}
t=0

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V5-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V9-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1



with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V10-different-seeds-registered/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12-registered-downstream/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

for exp in ['6b', '8b', '9b']:
    with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V{exp}-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'{exp}-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V11b-first-reconstruction-then-training-again/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-roc-auc'])
        # sns.histplot(b['test-roc-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V9c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        # l = len(b['test-pr-auc'])
        l = 5
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-roc-auc']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


res_df = pd.DataFrame(res_df)
sns.boxplot(data = res_df, x = 'score', y='test')
# Out:
# <Axes: xlabel='score', ylabel='test'>

# %%
import os
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# for exp in ['6', '6b', '8', '8b','9', '9b']:
tites = ['warm-start_train-both',
         'only downstream',
         'only downstream, registered',
         'warm start, train both, registered', 
         'warm-start, train-only-downstream, registered',
         'upstream-warm-downstream-cold-train-only-downstream',
         'warm-start_train-both_impute-only-missing',
         'warm-start_train-both_dynamic-reconstruction',
         'warm-start_train-both_impute-only-missing, reg downstream',
         'warm-start_train-both - registered correctly'
         'warm-start_train-both - registered correctly'
         ]

res_df = {
      'test':[],
      'score':[],
      'seed':[],
}
t=0

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V5-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V9-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1



with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V10-different-seeds-registered/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12-registered-downstream/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

for exp in ['6b', '8b', '9b']:
    with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V{exp}-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'{exp}-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V11b-first-reconstruction-then-training-again/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V9c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        # l = len(b['test-pr-auc'])
        l = 5
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc'][:5]
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1




# with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
#         b = pickle.load(handle)
#         # l = len(b['test-pr-auc'])
#         l = 5
#         # sns.histplot(b['test-pr-auc'])
#         # plt.xlim((0.6,0.8))
#         # plt.title(f'1b-{l} tests - {tites[t]}')
#         # plt.show()
#         res_df['score'] += b['test-pr-auc'][:5]
#         res_df['seed']  += b['seed']
#         res_df['test'] += l*[f'{tites[t]}']
#         t+=1


res_df['score'] += [.445,.439,0.439, 0.449, 0.442]
l = 5
res_df['test']  += l*[f'{tites[t]}']
res_df['seed']  += l*[222]

res_df = pd.DataFrame(res_df)
sns.boxplot(data = res_df, x = 'score', y='test')
# Out:
# <Axes: xlabel='score', ylabel='test'>

# %%
medians = pd.DataFrame(res_df.groupby('test')['score'].median()).reset_index()
res_df_ = res_df.merge(medians, on='test')
res_df_[res_df_['score_x'].round(5) == res_df_['score_y'].round(5)]
# Out:
#                                               test   score_x  seed   score_y
# 18                                 only downstream  0.432447   988  0.432447
# 108  warm-start, train-only-downstream, registered  0.403620   106  0.403620
# 163      warm-start_train-both_impute-only-missing  0.447104   365  0.447104
# 177   warm-start_train-both_dynamic-reconstruction  0.430350   510  0.430350

# %%
# warm-start_train-both_impute-only-missing: 365 
# only downstream, registered: 451

# %%
# res_df_[res_df_['test'] == 'only downstream, registered'].sort_values('score_x')

# %% [markdown]
# # Extracting Scores
# We want to take a given model and extract scores.

# %%
import os
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# for exp in ['6', '6b', '8', '8b','9', '9b']:
tites = ['warm-start_train-both',
         'only downstream',
         'only downstream, registered',
         'warm start, train both, registered', 
         'warm-start, train-only-downstream, registered',
         'upstream-warm-downstream-cold-train-only-downstream',
         'warm-start_train-both_impute-only-missing',
         'warm-start_train-both_dynamic-reconstruction',
         'warm-start_train-both_impute-only-missing, reg downstream',
         'warm-start_train-both - registered correctly',
         'warm-start_train-both - registered correctly'
         ]

res_df = {
      'test':[],
      'score':[],
      'seed':[],
}
t=0

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V5-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V9-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1



with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V10-different-seeds-registered/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1


with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12-registered-downstream/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

for exp in ['6b', '8b', '9b']:
    with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V{exp}-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'{exp}-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V11b-first-reconstruction-then-training-again/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V9c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        # l = len(b['test-pr-auc'])
        l = 5
        # sns.histplot(b['test-pr-auc'])
        # plt.xlim((0.6,0.8))
        # plt.title(f'1b-{l} tests - {tites[t]}')
        # plt.show()
        res_df['score'] += b['test-pr-auc'][:5]
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1




# with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
#         b = pickle.load(handle)
#         # l = len(b['test-pr-auc'])
#         l = 5
#         # sns.histplot(b['test-pr-auc'])
#         # plt.xlim((0.6,0.8))
#         # plt.title(f'1b-{l} tests - {tites[t]}')
#         # plt.show()
#         res_df['score'] += b['test-pr-auc'][:5]
#         res_df['seed']  += b['seed']
#         res_df['test'] += l*[f'{tites[t]}']
#         t+=1


res_df['score'] += [.445,.439,0.439, 0.449, 0.442]
l = 5
res_df['test']  += l*[f'{tites[t]}']
res_df['seed']  += l*[222]

res_df = pd.DataFrame(res_df)
sns.boxplot(data = res_df, x = 'score', y='test')
plt.show()

# %%
res_df['test'].unique()
# Out:
# array(['warm-start_train-both', 'only downstream',
#        'only downstream, registered',
#        'warm start, train both, registered',
#        'warm-start, train-only-downstream, registered',
#        'upstream-warm-downstream-cold-train-only-downstream',
#        'warm-start_train-both_impute-only-missing',
#        'warm-start_train-both_dynamic-reconstruction',
#        'warm-start_train-both_impute-only-missing, reg downstream',
#        'warm-start_train-both - registered correctly'], dtype=object)

# %%
mask = res_df['test'].isin(
    [
        'only downstream, registered',
        'warm-start_train-both - registered correctly'
    ]
)
sns.boxplot(data = res_df[mask], x = 'score', y='test')
plt.show()

# %%
res_df[mask]
# Out:
#                                              test     score  seed
# 29                    only downstream, registered  0.444227   510
# 30                    only downstream, registered  0.439268   365
# 31                    only downstream, registered  0.436926   382
# 32                    only downstream, registered  0.442812   322
# 33                    only downstream, registered  0.442565   988
# 34                    only downstream, registered  0.444500    98
# 35                    only downstream, registered  0.442759   742
# 36                    only downstream, registered  0.437488    17
# 37                    only downstream, registered  0.442222   595
# 38                    only downstream, registered  0.438358   106
# 39                    only downstream, registered  0.441183   123
# 40                    only downstream, registered  0.430659   569
# 41                    only downstream, registered  0.445973   214
# ...

# %%
res_df[['test','score']][res_df['test'].isin(["only downstream, registered", "warm-start_train-both - registered correctly"])].\
    groupby(['test'])['score'].mean()
# Out:
# test
# only downstream, registered                     0.441902
# warm-start_train-both - registered correctly    0.442800
# Name: score, dtype: float64

# %% [markdown]
# # Creating correct results
# - 9C is what I need - impute only missing, train both, worm start, registered

# %%
results = {
    'score_pr_auc':[],
    'score_roc_auc':[],
    'test':[],
}
with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V9c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
    b = pickle.load(handle)
    l = len(b['seed'])
    results['score_roc_auc'] += list(set(b['test-roc-auc']))
    results['score_pr_auc'] += list(set(b['test-pr-auc']))
    results['test']  += l*["Joint Optimization"]

with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V10-different-seeds-registered/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
    b = pickle.load(handle)
    l = len(b['seed'])
    results['score_roc_auc'] += list(set(b['test-roc-auc']))
    results['score_pr_auc'] += list(set(b['test-pr-auc']))
    results['test']  += l*["Naive Optimization"]
    
results_df = pd.DataFrame(results)
results_df
display(results_df.groupby(results_df['test'])['score_pr_auc','score_roc_auc'].mean())
display(results_df.groupby(results_df['test'])['score_pr_auc','score_roc_auc'].sem()*100)
display(results_df.groupby(results_df['test'])['score_pr_auc','score_roc_auc'].std()*100)
# Out:
# /tmp/ipykernel_1180352/1983600778.py:22: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   display(results_df.groupby(results_df['test'])['score_pr_auc','score_roc_auc'].mean())
#                     score_pr_auc  score_roc_auc
# test
# Joint Optimization      0.440497       0.717244
# Naive Optimization      0.441902       0.719848
# /tmp/ipykernel_1180352/1983600778.py:23: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   display(results_df.groupby(results_df['test'])['score_pr_auc','score_roc_auc'].sem()*100)
#                     score_pr_auc  score_roc_auc
# test
# Joint Optimization      0.139113       0.114809
# Naive Optimization      0.061235       0.040215
# ...

# %%
import os
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# for exp in ['6', '6b', '8', '8b','9', '9b']:
tites = [
        'only downstream, registered',
        'warm-start_train-both_impute-only-missing, reg downstream',

        'warm-start_train-both - registered correctly',
        'warm-start_train-both - registered correctly'
         ]

res_df = {
      'test':[],
      'score':[],
      'seed':[],
}
t=0
with open(f'/home/david/Desktop/projects/thesis/downstream_classification/models/AF-V10-different-seeds-registered/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        l = len(b['test-pr-auc'])
        res_df['score'] += b['test-pr-auc']
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1

with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V9c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
        res_df['score'] += b['test-pr-auc'][:5]
        res_df['seed']  += b['seed']
        res_df['test'] += l*[f'{tites[t]}']
        t+=1




# with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/AF-V12c-different-seeds/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
#         b = pickle.load(handle)
#         # l = len(b['test-pr-auc'])
#         l = 5
#         # sns.histplot(b['test-pr-auc'])
#         # plt.xlim((0.6,0.8))
#         # plt.title(f'1b-{l} tests - {tites[t]}')
#         # plt.show()
#         res_df['score'] += b['test-pr-auc'][:5]
#         res_df['seed']  += b['seed']
#         res_df['test'] += l*[f'{tites[t]}']
#         t+=1


res_df['score'] += [.445,.439,0.439, 0.449, 0.442]
l = 5
res_df['test']  += l*[f'{tites[t]}']
res_df['seed']  += l*[222]

res_df = pd.DataFrame(res_df)
sns.boxplot(data = res_df, x = 'score', y='test')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/7.0-Comparing_different_moedls-internal_data.ipynb Cell 17 in <cell line: 140>()
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2250432d6f6c642d776966692d646f6e676c65227d/home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/7.0-Comparing_different_moedls-internal_data.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=137'>138</a> res_df['score'] += [.445,.439,0.439, 0.449, 0.442]
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2250432d6f6c642d776966692d646f6e676c65227d/home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/7.0-Comparing_different_moedls-internal_data.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=138'>139</a> l = 5
# ...
